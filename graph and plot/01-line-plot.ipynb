# %% [markdown]
# ### important libaraies
# - seaborn
# - matlab

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool = sns.load_dataset("iris")
phool
sns.lineplot(x="sepal_length",y="petal_length",data=phool)

# %%
## for the title
import seaborn as sns
import matplotlib.pyplot as plt
phool = sns.load_dataset("iris")
phool
plt.title("data of phool")
sns.lineplot(x="sepal_length",y="petal_length",data=phool)

# %% [markdown]
# ## adding limits

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool = sns.load_dataset("iris")
phool
sns.lineplot(x="sepal_length",y="petal_length",data=phool)
plt.xlim(5)
plt.ylim(4)
# Out:
# (4, 7.137499999999999)

# %% [markdown]
# ## set style`

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool = sns.load_dataset("iris")
phool
sns.set_style(style=None,rc=None)
sns.lineplot(x="sepal_length",y="petal_length",data=phool)
plt.title("phool data")
sns.set_style("whitegrid")

# %% [markdown]
# ## change fig size

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool = sns.load_dataset("iris")
phool
plt.figure(figsize=(12,8)) # set fig size
sns.set_style(style=None,rc=None)
sns.lineplot(x="sepal_length",y="petal_length",data=phool)
plt.title("phool data")
# Out:
# Text(0.5, 1.0, 'phool data')
