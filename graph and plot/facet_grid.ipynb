# %%
import pandas as df
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=df.read_csv('chila')
data.head(2)
# Out:
#   Gender  Location    Age Qualification_completed    field_of_study  \
# 0   Male  Pakistan  36-40                 Masters  Natural Sciences
# 1   Male  Pakistan  26-30               Bachelors             CS/IT
#
#       Purpose_for_chilla What are you? Blood group   \
# 0  to boost my skill set     Unemplyed           B+
# 1  to boost my skill set       Student           B+
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
#
#   Your favorite programming language? Marital Status? Are you Vaccinated?  \
# 0                              Python             Yes                 Yes
# 1                              Python              No                 Yes
#
#   Where do you live? Research/Working experience (Float/Int) years  \
# 0              Urbun                                             5
# ...

# %%
x=sns.FacetGrid(row="Age",col="Marital Status?",data=data)
x=x.map(plt.hist,'Gender',color="red")

# %%
data.head(2)
# Out:
#   Gender  Location    Age Qualification_completed    field_of_study  \
# 0   Male  Pakistan  36-40                 Masters  Natural Sciences
# 1   Male  Pakistan  26-30               Bachelors             CS/IT
#
#       Purpose_for_chilla What are you? Blood group   \
# 0  to boost my skill set     Unemplyed           B+
# 1  to boost my skill set       Student           B+
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
#
#   Your favorite programming language? Marital Status? Are you Vaccinated?  \
# 0                              Python             Yes                 Yes
# 1                              Python              No                 Yes
#
#   Where do you live? Research/Working experience (Float/Int) years  \
# 0              Urbun                                             5
# ...

# %%
x=sns.FacetGrid(row="Age",col="Location",data=data)
x=x.map(plt.hist,'Prepaid or Postpaid')

# %%
x=sns.FacetGrid(row="Age",col="Location",data=data)
x=x.map(plt.hist,'Are you Vaccinated?')

# %%
data.head(2)
# Out:
#   Gender  Location    Age Qualification_completed    field_of_study  \
# 0   Male  Pakistan  36-40                 Masters  Natural Sciences
# 1   Male  Pakistan  26-30               Bachelors             CS/IT
#
#       Purpose_for_chilla What are you? Blood group   \
# 0  to boost my skill set     Unemplyed           B+
# 1  to boost my skill set       Student           B+
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
#
#   Your favorite programming language? Marital Status? Are you Vaccinated?  \
# 0                              Python             Yes                 Yes
# 1                              Python              No                 Yes
#
#   Where do you live? Research/Working experience (Float/Int) years  \
# 0              Urbun                                             5
# ...

# %%
x=sns.FacetGrid(row="Location",col="Marital Status?",data=data)
x=x.map(plt.scatter,'Are you Vaccinated?','Gender')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1852/367016363.py in <module>
# ----> 1 sns.FacetGrid(data ,x="smoker")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: __init__() got an unexpected keyword argument 'x'
