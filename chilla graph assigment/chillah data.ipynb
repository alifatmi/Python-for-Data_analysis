# %% [markdown]
# ### plot assignment
# - dataset python chila

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
chila =pd.read_csv('data_viz.csv') # loading the file
chila
# Out:
#              Timestamp  Gender    Age  Location Time_of_class  Duration
# 0    1/3/2022 19:09:29    Male  16-30  Pakistan         10:30        60
# 1    1/3/2022 19:09:33    Male  16-30  Pakistan         10:00        60
# 2    1/3/2022 19:09:33    Male  16-30  Pakistan         10:00        30
# 3    1/3/2022 19:09:33    Male  30-40  Pakistan         09:30        30
# 4    1/3/2022 19:09:34    Male  16-30      East         09:30        60
# ..                 ...     ...    ...       ...           ...       ...
# 301  1/3/2022 19:11:51    Male  16-30  Pakistan         09:30        30
# 302  1/3/2022 19:11:52    Male  16-30  Pakistan         10:30        45
# 303  1/3/2022 19:11:53    Male  16-30  Pakistan         10:00        60
# 304  1/3/2022 19:11:54  Female  16-30  Pakistan         10:30        60
# 305  1/3/2022 19:11:55    Male  16-30  Pakistan         10:30        45
#
# [306 rows x 6 columns]

# %%
# applying data on graph
p=sns.countplot(x='Gender' ,data=chila,hue='Duration')
plt.show()

# %%
p=sns.countplot(x='Gender' ,data=chila,hue='Location')
plt.show()

# %%
p=sns.countplot(x='Gender' ,data=chila,hue='Time_of_class')
plt.show()

# %%
p=sns.countplot(x='Gender' ,data=chila,hue='Age')
plt.show()

# %%
p=sns.countplot(x='Location' ,data=chila,hue='Age')
plt.show()

# %%
p=sns.countplot(x='Location' ,data=chila,hue='Time_of_class')
plt.show()

# %%
p=sns.countplot(x='Location' ,data=chila,hue='Duration')
plt.show()

# %%
chila.head()
# Out:
#            Timestamp Gender    Age  Location Time_of_class  Duration
# 0  1/3/2022 19:09:29   Male  16-30  Pakistan         10:30        60
# 1  1/3/2022 19:09:33   Male  16-30  Pakistan         10:00        60
# 2  1/3/2022 19:09:33   Male  16-30  Pakistan         10:00        30
# 3  1/3/2022 19:09:33   Male  30-40  Pakistan         09:30        30
# 4  1/3/2022 19:09:34   Male  16-30      East         09:30        60

# %%
sns.catplot(x="Location",y="Duration", hue="Age", data=chila,kind="bar")

# %%
sns.catplot(x="Location",y="Duration", hue="Time_of_class", data=chila,kind="bar")

# %%
sns.catplot(x="Location",y="Duration", hue="Gender", data=chila,kind="bar")

# %%
sns.catplot(x="Gender",y="Duration", hue="Location", data=chila,kind="bar")

# %%
sns.catplot(x="Gender",y="Duration", hue="Time_of_class", data=chila,kind="bar")

# %%
sns.catplot(x="Gender",y="Duration", hue="Age", data=chila,kind="bar")
